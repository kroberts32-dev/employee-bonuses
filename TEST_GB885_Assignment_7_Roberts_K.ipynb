# %% [markdown]
# <a href="https://colab.research.google.com/github/kroberts32-dev/employee-bonuses/blob/main/TEST_GB885_Assignment_7_Roberts_K.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #World Literacy Rate by Country
#
# Kasandra Roberts
#
# Dataset: https://www.kaggle.com/datasets/mathurinache/worldliteracyrateadulttotalbycountry

# %%
# install kaggle library
! pip install kaggle

# %%
# import libraries

import os
import pandas as pd

# %%
# create directory and copy API token file to directory
os.mkdir('/content/kaggle_dataset')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# /tmp/ipykernel_1721/3818493633.py in <cell line: 0>()
#       1 # create directory and copy API token file to directory
# ----> 2 os.mkdir('/content/kaggle_dataset')
#
# FileExistsError: [Errno 17] File exists: '/content/kaggle_dataset'

# %%
# copy kaggle.json to kaggle_data folder
os.rename('/content/kaggle.json', '/content/kaggle_dataset/kaggle.json')

# %%
# call kaggle test-file data from mathurinache/worldliteracyrateadulttotalbycountry
! kaggle datasets download mathurinache/worldliteracyrateadulttotalbycountry
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/mathurinache/worldliteracyrateadulttotalbycountry
# License(s): CC0-1.0
# ...
# 100% 10.9k/10.9k [00:00<00:00, 29.0MB/s]

# %%
# unzip file
! unzip worldliteracyrateadulttotalbycountry
# Out:
# Archive:  worldliteracyrateadulttotalbycountry.zip
#   inflating: World Literacy Rate Adult Total by Country.csv

# %%
# bring into Dataframe
# view first few records
literacy_df = pd.read_csv('World Literacy Rate Adult Total by Country.csv')
literacy_df.head()
# Out:
#                      English                                 Country Flag  \
# 0  Latin America & Caribbean  https://www.countryflags.io/aw/shiny/64.png
# 1                 South Asia  https://www.countryflags.io/af/shiny/64.png
# 2         Sub-Saharan Africa  https://www.countryflags.io/ao/shiny/64.png
# 3      Europe & Central Asia  https://www.countryflags.io/al/shiny/64.png
# 4      Europe & Central Asia  https://www.countryflags.io/ad/shiny/64.png
#
#      English.1 Country Name Country Code  \
# 0        Aruba        Aruba          ABW
# 1  Afghanistan  Afghanistan          AFG
# 2       Angola       Angola          AGO
# 3      Albania      Albania          ALB
# 4      Andorra      Andorra          AND
#
#                                       Indicator Name  Indicator Code  1960  \
# 0  Literacy rate, adult total (% of people ages 1...  SE.ADT.LITR.ZS   NaN
# 1  Literacy rate, adult total (% of people ages 1...  SE.ADT.LITR.ZS   NaN
# ...
